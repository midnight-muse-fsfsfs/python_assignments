# %%
# 1. CREATE A VAR 'CITY' AND ASSIGN THE NAME OF UR FAV CITY TO IT. PRINT THE VAR

# %%
city='NEW YORK'

# %%
print(city)
# Out:
# NEW YORK

# %%
# 2. PRINT THE DATA TYPE OF THE VAR 'CITY'

# %%
print(type(city))
# Out:
# <class 'str'>

# %%
# 3. CONVERT THE INT 42 TO A STRING AND ASSIG IT TO A NEW VAR . PRINT THE NEW VAR

# %%
t=type(42)

# %%
print(t)
# Out:
# <class 'int'>

# %%
v=type(str(42))

# %%
print(v)
# Out:
# <class 'str'>

# %%
# 4. USE len() ON UR NAME VAR AND COUNT LENGHT OF UR NAME

# %%
name='gunjan'

# %%
print(len(name))
# Out:
# 6

# %%
surname='tomar'

# %%
print(len(surname))
# Out:
# 5

# %%
print(len(name+surname))
# Out:
# 11

# %%
# 5. USE "IF" STATEMENT TO CHECK "CODE" WORD EXIST OR NOT IN "CODE SQUARE"

# %%
course= 'CODE SQUARE'

# %%
if 'code' in course:
        print("yes its present")
else:
     print("no sry better luck next tym");
# Out:
# no sry better luck next tym

# %%
if 'CODE' in course:
    print("yes, u guessed it correct")
else:
    print("No, u guessed it wrong again")
# Out:
# yes, u guessed it correct
