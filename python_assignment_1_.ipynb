# %%
5
# Out:
# 5

# %%
a=500
a-5
# Out:
# 495

# %%
flower=40
flower-32
# Out:
# 8

# %%
#assignment1: create 5 variable and string with diff val & print them using print() func

# %%
year=2025
print(year)
# Out:
# 2025

# %%
day='FRIDAY'
print(day)
# Out:
# FRIDAY

# %%
Name='Gunjan Tomar'
print(Name)
# Out:
# Gunjan Tomar

# %%
year1=2025
year2=2007
age= year1-year2
print(age)
# Out:
# 18

# %%
gift1=400
gift2=600
money= gift1-gift2
print(money)
# Out:
# -200
