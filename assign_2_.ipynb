# %%
# 1. CONCATINATE TWO VARIABLE OF UR NAME AND SURNAME

# %%
a='GUNJAN'
b=' TOMAR'

# %%
print(a+b)
# Out:
# GUNJAN TOMAR

# %%
# 2.  CREATE A STRING VARIABLE OF UR NAME AND SURNAME,SLICE A STRING USING INDEXING SO IT WILL PRTINT UR 1ST NAME

# %%
name="gunjan tomar"

# %%
name[0:4]
# Out:
# 'gunj'

# %%
print(type(name[0:6]))
# Out:
# <class 'str'>

# %%
for item in name:
    print(item[:9])
# Out:
# g
# u
# n
# j
# a
# n
#
# t
# o
# m
# a
# r

# %%
for item in name:
    print(name[:-2])
# Out:
# gunjan tom
# gunjan tom
# gunjan tom
# gunjan tom
# gunjan tom
# gunjan tom
# gunjan tom
# gunjan tom
# gunjan tom
# gunjan tom
# gunjan tom
# gunjan tom

# %%
# 3. CREATE A LIST WITH DIFF STATES OF INDIA

# %%
i=['SIKKIM', 'MAHARASHTRA', 'KERALA', 'GOA', 'TAMIL NADU']

# %%
# 4. use for loop to print items from list

# %%
for item in i:
    print(item)
# Out:
# SIKKIM
# MAHARASHTRA
# KERALA
# GOA
# TAMIL NADU

# %%
for item in i:
    print(i)
# Out:
# ['SIKKIM', 'MAHARASHTRA', 'KERALA', 'GOA', 'TAMIL NADU']
# ['SIKKIM', 'MAHARASHTRA', 'KERALA', 'GOA', 'TAMIL NADU']
# ['SIKKIM', 'MAHARASHTRA', 'KERALA', 'GOA', 'TAMIL NADU']
# ['SIKKIM', 'MAHARASHTRA', 'KERALA', 'GOA', 'TAMIL NADU']
# ['SIKKIM', 'MAHARASHTRA', 'KERALA', 'GOA', 'TAMIL NADU']
